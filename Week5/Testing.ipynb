# %% [markdown]
# # Testing
# ### make sure code still works
# 7 July 2025<br>
# NRSC 7657<br>
# Daniel J Denman and John Thompson<br>
# University of Colorado Anschutz<br>
# <br>

# %% [markdown]
# Testing is usually done outside of the notebook, so this notebook contains mostly instructions and questions

# %% [markdown]
# ## use an existing packages tests: patsy

# %% [markdown]
# ### Q1 first, install the package `patsy`, an older package for certain kinds of statistical models. we will also need `pytest`
# the exact package we use (in this case `patsy`) as an example of testing is not critical, just one that uses tests. we're using this one, because you probably won't ever use it and it won't affect any of your actual work. you can use `pip` from the command line (if you have activated your NRSC7657 environment) or from this notebook (if you are using the relevant python kernel).

# %% [markdown]
# ## Q2 run the `patsy` tests.
# #### Using a terminal (in the VS Code bottom pane, or Terminal (mac) or Anaconda Prompt (windows)), activate you NRSC7657 environment, and navigate to the installed `patsy` folder. Once your terminal's current directory is there, execute the `pytest` function from this folder. (you can check the `pytest` [docs](https://docs.pytest.org/en/6.2.x/getting-started.html) for some help)

# %% [markdown]
# your terminal should look something like this:
# ![Alt text](./media/test1.png)

# %% [markdown]
# ## Q3 Break a `patsy` test.
# #### Let's imagine you want to "improve" the regression code in this project. you do so by changing the implementation of `build_design_matrices` (at the very end of `build.py` in the `patsy` folder). You could change it any way, but let's just say you change the final line to read `return results` instead of `return matrices` by mistake.

# %% [markdown]
# ## Q4 rerun `pytest` on `patsy` now that we've messed with it
# what happened?

# %% [markdown]
# ## create your own tests for the functions and classes we've been using in class, and run them.
# we are going to use the 'djd' folder in this Week5 folder, which is a dummy package-style folder provided for you. in it is an importable module, `stuff.py`, which contains two classes that we have worked with throughout the course, and potentially some extra stuff. There is also skeleton of test file, `test_classes.py`. It is important to note that this file starts with  `test_` so that `pytest` knows to run it when `pytest` is executed

# %% [markdown]
# ## Q5 in `test_classes.py`, add a test function called `test_thing()` that ensures `ThingWeMade` is behaving as expected.
# #### To do this, create an instance of `ThingWeMade`, change the instances' `spike` attribute to fire 'projectile'. Finally, get your instance's spike attribute and assigne it to a variable `fired`.
# in the skeleton, there is a final `assert` statement, which is how the test is checking your code against an expected answer. this is how the test is evaluated.

# %% [markdown]
# ## Q6 Write a test in `test_classes.py` called `test_betterthing()` that tests if you can use `ABetterThing` to create the string "curiosity got the better"

# %% [markdown]
# ## Q7 run `pytest` on `djd`. your output should look something like this:
# ![Alt text](./media/test2.png)
