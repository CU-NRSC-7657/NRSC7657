# %% [markdown]
# # Usability: Documentation
# ### some neuroscience data
# 30 June 2025<br>
# NRSC 7657<br>
# Daniel J Denman and John Thompson<br>
# University of Colorado Anschutz<br>
# <br>

# %% [markdown]
# # The place to start with python documentation is this classic PEP:
# https://peps.python.org/pep-0257/

# %% [markdown]
# ## Q1 add a one-line doc string to this `Class`

# %%
class ThingWeMade:
    def __init__(self):
        self.thing='neuron'
        
        self.start()
    
    def start(self):
        self.thing2='neuron'
        
    def fire(self):
        self.spike = self.thing+' fires an action potential'
        print(self.spike)
        
    def fire_a_thing(self,input_string):
        self.spike = self.thing+' fires an '+input_string
        print(self.spike)

    def emit_a_thing(self, input_string):
        return self.thing+' fires an '+input_string

# %% [markdown]
# ## Q2 add multi-line docstrings to the same class. make sure to cover inputs (keyword parameters) and outputs (return values)

# %%
class ThingWeMade:
    def __init__(self):
        self.thing='neuron'
        
        self.start()
    
    def start(self):
        self.thing2='neuron'
        
    def fire(self):
        self.spike = self.thing+' fires an action potential'
        print(self.spike)
        
    def fire_a_thing(self,input_string):
        self.spike = self.thing+' fires an '+input_string
        print(self.spike)

    def emit_a_thing(self, input_string):
        return self.thing+' fires an '+input_string

# %% [markdown]
# ## Q3 add whatever you think the appropriate doc string are for this class extension

# %%
class ABetterThing(ThingWeMade):
    def __init__(self):
        self.newthing='better'
        ThingWeMade.__init__(self)
        
    def make_it_better(self):
        print(self.thing+' '+self.newthing)

# %% [markdown]
# VS Code has an extenstion that will autogenerate doc strings: https://marketplace.visualstudio.com/items?itemName=njpwerner.autodocstring
# <br>
# you can try it out if you'd like; MATLAB has similar functionality
